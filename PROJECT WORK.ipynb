# %%
import numpy
import pandas
import sklearn
import seaborn
import matplotlib.pyplot as pltk
from pylab import rcParams
rcParams['figure.figsize']=10,8
from sklearn import datasets,linear_model
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.linear_model import LogisticRegression
from sklearn import tree
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#creating dataframe
book_df = pandas.read_csv('C:/Users/SCHOOL/Desktop/Book_Rating.csv')

# %%
#check the data
book_df
# Out:
#            rowid  User-ID        ISBN  Book-Rating
# 0              0   276725  034545104X            0
# 1              1   276726   155061224            5
# 2              2   276727   446520802            0
# 3              3   276729  052165615X            3
# 4              4   276729   521795028            6
# 5              5   276733  2080674722            0
# 6              6   276736  3257224281            8
# 7              7   276737   600570967            6
# 8              8   276744  038550120X            7
# 9              9   276745   342310538           10
# 10            10   276746   425115801            0
# 11            11   276746   449006522            0
# 12            12   276746   553561618            0
# 13            13   276746  055356451X            0
# 14            14   276746   786013990            0
# 15            15   276746   786014512            0
# 16            16   276747    60517794            9
# ...

# %%
#take dependent and independent variables seperation
book_df_x=book_df[['User-ID','ISBN']]
book_df_y=book_df[['Book-Rating']]

# %%
book_df_x
book_df_y
# Out:
#          Book-Rating
# 0                  0
# 1                  5
# 2                  0
# 3                  3
# 4                  6
# 5                  0
# 6                  8
# 7                  6
# 8                  7
# 9                 10
# 10                 0
# 11                 0
# 12                 0
# 13                 0
# 14                 0
# 15                 0
# 16                 9
# 17                 0
# 18                 0
# 19                 9
# 20                 8
# 21                 7
# 22                 0
# 23                 7
# 24                 6
# 25                 0
# 26                 0
# 27                 8
# 28                 8
# 29                 5
# ...              ...
# 1048545            0
# 1048546            0
# 1048547            0
# 1048548            0
# 1048549            0
# 1048550            0
# 1048551            0
# 1048552            0
# 1048553            0
# 1048554            0
# 1048555            0
# ...

# %%
#split train and test set
x_train,x_test,y_train,y_test=train_test_split(book_df_x,book_df_y,test_size=0.20)

# %%
x_train,x_test,y_train,y_test
# Out:
# (         User-ID        ISBN
#  800498    194514  8835600901
#  208557     48268   451169514
#  344311     82091  951311886X
#  622276    150896   802487785
#  570972    137190  2020220989
#  820451    198711   590417916
#  617930    149647  849550152X
#  244742     56272   743252071
#  945150    228998  044022165X
#  857857    207369   971191522
#  696047    169755   425080021
#  191838     42458   671793543
#  308079     73588   451181379
#  1045907   250278   553212419
#  339065     80908  848432365X
#  515998    125039   316030864
#  238023     55490   425098648
#  954405    230635  031027771X
#  538353    129368   425183750
#  296612     70183   879514175
#  646691    156269   312856660
#  107096     24627   425177009
#  1041008   249058  1551669153
#  1036318   247752   140482121
#  418787     99955   590437232
#  989024    238008   380814803
#  49393      11676   425171272
#  612451    148154  8408020927
#  519764    125774   515132020
#  146690     32773   671700294
# ...

# %%
#we will perform z-score normalization on both these
userid_scaler=StandardScaler()
userid_scaler.fit(pandas.DataFrame(x_train['User-ID']))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
x_train[['User-ID']]=userid_scaler.transform(x_train[['User-ID']])

# %%
x_train
# Out:
#           User-ID        ISBN
# 800498   0.889267  8835600901
# 208557  -1.081100   451169514
# 344311  -0.625404  951311886X
# 622276   0.301603   802487785
# 570972   0.116943  2020220989
# 820451   0.945813   590417916
# 617930   0.284776  849550152X
# 244742  -0.973262   743252071
# 945150   1.353869  044022165X
# 857857   1.062462   971191522
# 696047   0.555690   425080021
# 191838  -1.159378   671793543
# 308079  -0.739964   451181379
# 1045907  1.640573   553212419
# 339065  -0.641342  848432365X
# 515998  -0.046767   316030864
# 238023  -0.983798   425098648
# 954405   1.375924  031027771X
# 538353   0.011557   425183750
# 296612  -0.785840   879514175
# 646691   0.373994   312856660
# 107096  -1.399614   425177009
# 1041008  1.624136  1551669153
# 1036318  1.606541   140482121
# 418787  -0.384723   590437232
# 989024   1.475260   380814803
# 49393   -1.574103   425171272
# 612451   0.264661  8408020927
# 519764  -0.036864   515132020
# 146690  -1.289863   671700294
# ...

# %%
#we will perform encoder
isbn_encoder=preprocessing.LabelEncoder()
isbn_encoder.fit(pandas.DataFrame(x_train['ISBN']))
# Out:
# LabelEncoder()

# %%
x_train[['ISBN']]=isbn_encoder.transform(x_train['ISBN'])

# %%
x_train
# Out:
#           User-ID    ISBN
# 800498   0.889267  259390
# 208557  -1.081100  145028
# 344311  -0.625404  273924
# 622276   0.301603  223428
# 570972   0.116943   55692
# 820451   0.945813  169614
# 617930   0.284776  248841
# 244742  -0.973262  208227
# 945150   1.353869    7334
# 857857   1.062462  277360
# 696047   0.555690  127814
# 191838  -1.159378  191262
# 308079  -0.739964  145375
# 1045907  1.640573  160163
# 339065  -0.641342  247784
# 515998  -0.046767   74513
# 238023  -0.983798  128051
# 954405   1.375924    2829
# 538353   0.011557  129744
# 296612  -0.785840  255706
# 646691   0.373994   71956
# 107096  -1.399614  129506
# 1041008  1.624136   28019
# 1036318  1.606541   24157
# 418787  -0.384723  170115
# 989024   1.475260  114513
# 49393   -1.574103  129310
# 612451   0.264661  238054
# 519764  -0.036864  153463
# 146690  -1.289863  189677
# ...           ...     ...
# 189048  -1.169617  130793
# 161372  -1.248286  190131
# 996654   1.489474   74105
# ...

# %%
#we will perform z-score normalization on both these
isbn_scaler=StandardScaler()
isbn_scaler.fit(pandas.DataFrame(x_train['ISBN']))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
x_train[['ISBN']]=isbn_scaler.transform(x_train[['ISBN']])

# %%
x_train
# Out:
#           User-ID      ISBN
# 800498   0.889267  1.704421
# 208557  -1.081100  0.138942
# 344311  -0.625404  1.903374
# 622276   0.301603  1.212144
# 570972   0.116943 -1.083960
# 820451   0.945813  0.475495
# 617930   0.284776  1.560018
# 244742  -0.973262  1.004061
# 945150   1.353869 -1.745923
# 857857   1.062462  1.950408
# 696047   0.555690 -0.096697
# 191838  -1.159378  0.771830
# 308079  -0.739964  0.143692
# 1045907  1.640573  0.346122
# 339065  -0.641342  1.545549
# 515998  -0.046767 -0.826323
# 238023  -0.983798 -0.093452
# 954405   1.375924 -1.807591
# 538353   0.011557 -0.070277
# 296612  -0.785840  1.653991
# 646691   0.373994 -0.861325
# 107096  -1.399614 -0.073535
# 1041008  1.624136 -1.462770
# 1036318  1.606541 -1.515636
# 418787  -0.384723  0.482353
# 989024   1.475260 -0.278771
# 49393   -1.574103 -0.076218
# 612451   0.264661  1.412357
# 519764  -0.036864  0.254407
# 146690  -1.289863  0.750134
# ...           ...       ...
# 189048  -1.169617 -0.055918
# ...

# %%
x_train_original=x_train
x_train=x_train.values
y_train=y_train.values

# %%
#create linear regression obj
simple_linear_regression=LinearRegression()

# %%
#fit the data
simple_linear_regression.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
x_test
# Out:
#          User-ID        ISBN
# 954446    230687   446611867
# 923056    224764   451195493
# 13786       1903   439139597
# 950789    230427  3462033204
# 957069    231210   801037182
# 569416    136473   553290851
# 408800     98391    45120561
# 667206    162266   345370139
# 926115    225199   812571290
# 236030     54969  3442447666
# 31459       7326   451453824
# 235314     54656    99387913
# 740050    178919   140390197
# 85100      18012   684841347
# 497442    119858   135462681
# 594099    143253   307988619
# 818422    198711   439133211
# 361029     87141    60913916
# 88150      19285   241139988
# 691105    168144  1891620150
# 152297     34801   375708669
# 384344     93047   316143464
# 285821     68309   886775426
# 732559    177090   451180321
# 944950    228998   373710933
# 637913    153662  1575665611
# 16189       2719   441009700
# 846795    204864   446311812
# 542609    130474   515121487
# 149157     33763   842342702
# ...          ...         ...
# ...

# %%
#we will perform z-score normalization on both these
userid_scaler=StandardScaler()
userid_scaler.fit(pandas.DataFrame(x_test['User-ID']))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
x_test[['User-ID']]=userid_scaler.transform(x_test[['User-ID']])

# %%
x_test
# Out:
#           User-ID        ISBN
# 954446   1.377082   446611867
# 923056   1.297260   451195493
# 13786   -1.706147   439139597
# 950789   1.373578  3462033204
# 957069   1.384130   801037182
# 569416   0.107398   553290851
# 408800  -0.405818    45120561
# 667206   0.455000   345370139
# 926115   1.303122   812571290
# 236030  -0.990998  3442447666
# 31459   -1.633064   451453824
# 235314  -0.995216    99387913
# 740050   0.679426   140390197
# 85100   -1.489053   684841347
# 497442  -0.116516   135462681
# 594099   0.198769   307988619
# 818422   0.946154   439133211
# 361029  -0.557429    60913916
# 88150   -1.471897   241139988
# 691105   0.534215  1891620150
# 152297  -1.262794   375708669
# 384344  -0.477836   316143464
# 285821  -0.811220   886775426
# 732559   0.654777   451180321
# 944950   1.354320   373710933
# 637913   0.339047  1575665611
# 16189   -1.695150   441009700
# 846795   1.029076   446311812
# 542609   0.026552   515121487
# 149157  -1.276783   842342702
# ...

# %%
isbn_encoder=preprocessing.LabelEncoder()
isbn_encoder.fit(pandas.DataFrame(x_test['ISBN']))
# Out:
# LabelEncoder()

# %%
x_test[['ISBN']]=isbn_encoder.transform(x_test['ISBN'])

# %%
x_test
# Out:
#           User-ID    ISBN
# 954446   1.377082   55825
# 923056   1.297260   58578
# 13786   -1.706147   51601
# 950789   1.373578   34644
# 957069   1.384130   90563
# 569416   0.107398   65957
# 408800  -0.405818   58849
# 667206   0.455000   33403
# 926115   1.303122   93506
# 236030  -0.990998   31559
# 31459   -1.633064   59481
# 235314  -0.995216  109891
# 740050   0.679426    9409
# 85100   -1.489053   81384
# 497442  -0.116516    7041
# 594099   0.198769   25142
# 818422   0.946154   51579
# 361029  -0.557429   71697
# 88150   -1.471897   23162
# 691105   0.534215   19654
# 152297  -1.262794   42267
# 384344  -0.477836   28033
# 285821  -0.811220  103767
# 732559   0.654777   58295
# 944950   1.354320   40670
# 637913   0.339047   15543
# 16189   -1.695150   54021
# 846795   1.029076   54647
# 542609   0.026552   61861
# 149157  -1.276783   96973
# ...           ...     ...
# 596024   0.205036   63244
# 455066  -0.257952   59614
# 395575  -0.446679    7638
# ...

# %%
#we will perform z-score normalization on both these
isbn_scaler=StandardScaler()
isbn_scaler.fit(pandas.DataFrame(x_test['ISBN']))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
x_test[['ISBN']]=isbn_scaler.transform(x_test[['ISBN']])

# %%
x_test
# Out:
#           User-ID      ISBN
# 954446   1.377082  0.064982
# 923056   1.297260  0.157466
# 13786   -1.706147 -0.076919
# 950789   1.373578 -0.646574
# 957069   1.384130  1.231971
# 569416   0.107398  0.405357
# 408800  -0.405818  0.166570
# 667206   0.455000 -0.688264
# 926115   1.303122  1.330839
# 236030  -0.990998 -0.750211
# 31459   -1.633064  0.187802
# 235314  -0.995216  1.881277
# 740050   0.679426 -1.494319
# 85100   -1.489053  0.923612
# 497442  -0.116516 -1.573870
# 594099   0.198769 -0.965784
# 818422   0.946154 -0.077659
# 361029  -0.557429  0.598186
# 88150   -1.471897 -1.032300
# 691105   0.534215 -1.150148
# 152297  -1.262794 -0.390486
# 384344  -0.477836 -0.868664
# 285821  -0.811220  1.675547
# 732559   0.654777  0.147959
# 944950   1.354320 -0.444136
# 637913   0.339047 -1.288253
# 16189   -1.695150  0.004378
# 846795   1.029076  0.025408
# 542609   0.026552  0.267755
# 149157  -1.276783  1.447309
# ...           ...       ...
# 596024   0.205036  0.314216
# ...

# %%
#make predictions using trainning sets
y_pred=simple_linear_regression.predict(pandas.DataFrame(x_test))

# %%
y_pred
# Out:
# array([[2.62233461],
#        [2.64121989],
#        [3.2015524 ],
#        ...,
#        [2.61643095],
#        [2.79041887],
#        [2.68156049]])

# %%
print(r2_score(y_test,y_pred))
# Out:
# 0.002799382268098616

# %%
#make mean squared error using trainning sets
print("mean squared error:%.1f"% mean_squared_error(y_test,y_pred))
# Out:
# mean squared error:14.8

# %%
#make mean absolute error using trainning sets
print("mean absolute error:%2f"% mean_absolute_error(y_test,y_pred))
# Out:
# mean absolute error:3.576897

# %%
y_pred
# Out:
# array([[2.62233461],
#        [2.64121989],
#        [3.2015524 ],
#        ...,
#        [2.61643095],
#        [2.79041887],
#        [2.68156049]])

# %% [markdown]
# # naive bayes

# %%
#train the model using training sets
naive_bayes=GaussianNB()
naive_bayes.fit(x_train,y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
#make predictions using training sets
y_pred=naive_bayes.predict(x_test)
print(accuracy_score(y_test,y_pred))
# Out:
# 0.6215864387382877

# %% [markdown]
# # random forest

# %%
#train the model using training sets
random_forest=RandomForestClassifier()
random_forest.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
#make predictions using training sets
y_pred=random_forest.predict(x_test)

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.536065612855542

# %% [markdown]
# # decision tree

# %%
#train the model using training sets
decision_tree=tree.DecisionTreeClassifier()

# %%
decision_tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
#check on test data
y_pred=decision_tree.predict(x_test)
y_pred_prob=decision_tree.predict_proba(x_test)

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.3633645661969816

# %%
mean=30
sigma=10
isbn=numpy.sort(numpy.random.normal(mean,sigma,50).astype(int))
bookrating=numpy.sort(numpy.random.normal(mean,sigma,50).astype(int))
plt.scatter(isbn,bookrating)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-142-ac82e87dcc3f> in <module>
#       3 isbn=numpy.sort(numpy.random.normal(mean,sigma,50).astype(int))
#       4 bookrating=numpy.sort(numpy.random.normal(mean,sigma,50).astype(int))
# ----> 5 plt.scatter(isbn,bookrating)
#
# NameError: name 'plt' is not defined
